# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews_all

# %%
us_reviews = reviews_all(
    'com.knudge.me'
)

# %%
df = pd.DataFrame(np.array(us_reviews), columns = ['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                                    reviewId               userName  \
# 0      d24c99ea-e588-414a-8218-9e2caecf2452  Jhanna Eliaza Serrano
# 1      dc8f74ec-f767-4bea-b954-00d44701f741              Lara Daou
# 2      4c9a9bfe-34a9-4bda-b74d-315c46c6aa88        Prashant Sharma
# 3      d701a64e-5ef1-495b-8285-edc3ec2b5ef8        Pranit Mahamuni
# 4      4dbd68a2-674e-4bc2-a0ee-658a22b89a53            विकास आज़ाद
# ...                                     ...                    ...
# 14664  c34ad7b4-8264-46f4-bc52-118806684201          A Google user
# 14665  dee02f51-1237-467b-847a-164c12ed872c          A Google user
# 14666  35083976-8dde-4602-8236-b1fe0bc3ba12          A Google user
# 14667  913e07dd-936f-4f13-a880-2ce800cfa540          A Google user
# 14668  d4b328d4-634d-4535-ba59-60a065c8443e          A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/AD5-W...
# 1      https://play-lh.googleusercontent.com/a-/AD5-W...
# 2      https://play-lh.googleusercontent.com/a/AEdFTp...
# 3      https://play-lh.googleusercontent.com/a/AEdFTp...
# 4      https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                  ...
# 14664  https://play-lh.googleusercontent.com/EGemoI2N...
# 14665  https://play-lh.googleusercontent.com/EGemoI2N...
# 14666  https://play-lh.googleusercontent.com/EGemoI2N...
# 14667  https://play-lh.googleusercontent.com/EGemoI2N...
# 14668  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0                                     great app, thank u      5
# 1      You can find everything you need in there to i...      5
# 2              Veey good app to improve one's vocabulary      5
# 3              Best app for improving english vocabulary      5
# 4                                                      👍      1
# ...                                                  ...    ...
# 14664  This is a great app... and everybody must inst...      5
# 14665  Learning is easy and fun with the app.Good use...      5
# 14666                                  Informative App 😊      5
# 14667                         Amazing app much needed...      5
# 14668                                   I love this app.      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                  0                3.0.4 2023-01-22 12:19:27         None
# 1                  0                3.0.4 2023-01-21 15:02:25         None
# 2                  0                3.0.4 2023-01-20 16:31:23         None
# 3                  0                3.0.4 2023-01-20 09:48:11         None
# 4                  0                3.0.4 2023-01-17 02:59:59         None
# ...              ...                  ...                 ...          ...
# 14664              1                1.0.0 2016-07-27 12:06:37         None
# 14665              2                1.0.0 2016-07-27 11:54:03         None
# 14666              1                1.0.0 2016-07-27 11:11:41         None
# 14667              1                 None 2016-07-27 02:57:46         None
# 14668              1                1.0.0 2016-07-27 02:42:01         None
#
#       repliedAt
# 0           NaT
# 1           NaT
# 2           NaT
# 3           NaT
# 4           NaT
# ...         ...
# 14664       NaT
# 14665       NaT
# 14666       NaT
# 14667       NaT
# 14668       NaT
#
# [14669 rows x 10 columns]

# %%
from textblob import TextBlob

# %%
df['calculated'] = df['content'].apply(lambda x: (TextBlob(x).sentiment.polarity))
df
# Out:
#                                    reviewId               userName  \
# 0      d24c99ea-e588-414a-8218-9e2caecf2452  Jhanna Eliaza Serrano
# 1      dc8f74ec-f767-4bea-b954-00d44701f741              Lara Daou
# 2      4c9a9bfe-34a9-4bda-b74d-315c46c6aa88        Prashant Sharma
# 3      d701a64e-5ef1-495b-8285-edc3ec2b5ef8        Pranit Mahamuni
# 4      4dbd68a2-674e-4bc2-a0ee-658a22b89a53            विकास आज़ाद
# ...                                     ...                    ...
# 14664  c34ad7b4-8264-46f4-bc52-118806684201          A Google user
# 14665  dee02f51-1237-467b-847a-164c12ed872c          A Google user
# 14666  35083976-8dde-4602-8236-b1fe0bc3ba12          A Google user
# 14667  913e07dd-936f-4f13-a880-2ce800cfa540          A Google user
# 14668  d4b328d4-634d-4535-ba59-60a065c8443e          A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/AD5-W...
# 1      https://play-lh.googleusercontent.com/a-/AD5-W...
# 2      https://play-lh.googleusercontent.com/a/AEdFTp...
# 3      https://play-lh.googleusercontent.com/a/AEdFTp...
# 4      https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                  ...
# 14664  https://play-lh.googleusercontent.com/EGemoI2N...
# 14665  https://play-lh.googleusercontent.com/EGemoI2N...
# 14666  https://play-lh.googleusercontent.com/EGemoI2N...
# 14667  https://play-lh.googleusercontent.com/EGemoI2N...
# 14668  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0                                     great app, thank u      5
# 1      You can find everything you need in there to i...      5
# 2              Veey good app to improve one's vocabulary      5
# 3              Best app for improving english vocabulary      5
# 4                                                      👍      1
# ...                                                  ...    ...
# 14664  This is a great app... and everybody must inst...      5
# 14665  Learning is easy and fun with the app.Good use...      5
# 14666                                  Informative App 😊      5
# 14667                         Amazing app much needed...      5
# 14668                                   I love this app.      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                  0                3.0.4 2023-01-22 12:19:27         None
# 1                  0                3.0.4 2023-01-21 15:02:25         None
# 2                  0                3.0.4 2023-01-20 16:31:23         None
# 3                  0                3.0.4 2023-01-20 09:48:11         None
# 4                  0                3.0.4 2023-01-17 02:59:59         None
# ...              ...                  ...                 ...          ...
# 14664              1                1.0.0 2016-07-27 12:06:37         None
# 14665              2                1.0.0 2016-07-27 11:54:03         None
# 14666              1                1.0.0 2016-07-27 11:11:41         None
# 14667              1                 None 2016-07-27 02:57:46         None
# 14668              1                1.0.0 2016-07-27 02:42:01         None
#
#       repliedAt  calculated
# 0           NaT    0.800000
# 1           NaT    0.362083
# 2           NaT    0.700000
# 3           NaT    0.500000
# 4           NaT    0.000000
# ...         ...         ...
# 14664       NaT    0.571667
# 14665       NaT    0.223413
# 14666       NaT    0.000000
# 14667       NaT    0.400000
# 14668       NaT    0.500000
#
# [14669 rows x 11 columns]

# %%
writer = pd.ExcelWriter('output2.xlsx')
df.to_excel(writer)
writer.close()
